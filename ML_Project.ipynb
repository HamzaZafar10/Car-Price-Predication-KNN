# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Iqbal-0/Car-Price-Predication-by-KNN/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#all libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %%
data =pd.read_csv('/content/CAR model.csv')

# %% [markdown]
# 2) Top 5 Rows of Dataset

# %%
data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# 3) Last 5 Row of Dataset

# %%
data.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %% [markdown]
#  6) Find Shape of Dataset Number of Rows And Number of Columns

# %%
data.shape
# Out:
# (4340, 8)

# %% [markdown]
# 5) Information About Dataset Like the Total Number of Rows, Total Number of Columns, Data types of Each Column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %% [markdown]
# 6) Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %% [markdown]
# 7) Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
data.head(2)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
#
#   seller_type transmission        owner
# 0  Individual       Manual  First Owner
# 1  Individual       Manual  First Owner

# %% [markdown]
# 8) Data Preprocessing

# %%
date_time = datetime.datetime.now()

# %%
data['Age']=date_time.year - data['year']

# %%
data.head(5)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  Age
# 0  Individual       Manual   First Owner   17
# 1  Individual       Manual   First Owner   17
# 2  Individual       Manual   First Owner   12
# 3  Individual       Manual   First Owner    7
# 4  Individual       Manual  Second Owner   10

# %%
data.drop('year',axis=1,inplace=True)

# %% [markdown]
# 9) Outlier Removal

# %%
sns.boxplot(x=data['selling_price'])
plt.gca().xaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter("{x:,.0f}"))

# %%
sorted(data['selling_price'],reverse=True)
# Out:
# [8900000,
#  8150000,
#  5500000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4800000,
#  4800000,
#  4700000,
#  4500000,
#  4500000,
#  4500000,
#  4400000,
#  4400000,
#  4200000,
#  4000000,
#  4000000,
#  4000000,
#  3899000,
#  3899000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3500000,
#  3500000,
#  3256000,
#  3200000,
#  3200000,
#  3200000,
#  3100000,
#  3100000,
#  3100000,
#  3050000,
#  2900000,
#  2900000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2675000,
#  2675000,
#  2650000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2595000,
#  2575000,
#  2550000,
# ...

# %%
data[(data['selling_price']>= 8150000) & (data['selling_price']<=8900000)]
# Out:
#                                                    name  selling_price  \
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance        8900000
#
#       km_driven    fuel seller_type transmission        owner  Age
# 89         6500  Diesel      Dealer    Automatic  First Owner    7
# 3872      13000  Petrol      Dealer    Automatic  First Owner    8

# %%
data = data[~(data['selling_price']>= 7200000) & (data['selling_price']<=10000000)]

# %%
sns.boxplot(x=data['selling_price'])
plt.gca().xaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter("{x:,.0f}"))

# %%
data.shape
# Out:
# (4338, 8)

# %%
data.head(3)
# Out:
#                        name  selling_price  km_driven    fuel seller_type  \
# 0             Maruti 800 AC          60000      70000  Petrol  Individual
# 1  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
# 2      Hyundai Verna 1.6 SX         600000     100000  Diesel  Individual
#
#   transmission        owner  Age
# 0       Manual  First Owner   17
# 1       Manual  First Owner   17
# 2       Manual  First Owner   12

# %% [markdown]
# 10) Encoding the Categorical Columns

# %%
data['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
data['fuel'] = data['fuel'].map({'Diesel':0,'CNG':1,'LPG':2 ,'Electric':3 ,'Petrol':4})

# %%
data['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
data['seller_type'] = data['seller_type'].map({'Individual':0,'Dealer':1,'Trustmark Dealer':2 })

# %%
data['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['transmission'] = data['transmission'].map({'Manual':0,'Automatic':1})

# %%
data['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
data['owner'] = data['owner'].map({'First Owner':0,'Second Owner':1,'Third Owner':2 ,'Fourth & Above Owner':3,'Test Drive Car':4})

# %%
data.head(3)
# Out:
#                        name  selling_price  km_driven  fuel  seller_type  \
# 0             Maruti 800 AC          60000      70000     4            0
# 1  Maruti Wagon R LXI Minor         135000      50000     4            0
# 2      Hyundai Verna 1.6 SX         600000     100000     0            0
#
#    transmission  owner  Age
# 0             0      0   17
# 1             0      0   17
# 2             0      0   12

# %% [markdown]
# 11) Store Feature Matrix In X and Response In Vector y

# %%
X = data.drop(['name','selling_price'],axis=1)
y = data['selling_price']

# %%
X
# Out:
#       km_driven  fuel  seller_type  transmission  owner  Age
# 0         70000     4            0             0      0   17
# 1         50000     4            0             0      0   17
# 2        100000     0            0             0      0   12
# 3         46000     4            0             0      0    7
# 4        141000     0            0             0      1   10
# ...         ...   ...          ...           ...    ...  ...
# 4335      80000     0            0             0      1   10
# 4336      80000     0            0             0      1   10
# 4337      83000     4            0             0      1   15
# 4338      90000     0            0             0      0    8
# 4339      40000     4            0             0      0    8
#
# [4338 rows x 6 columns]

# %%
y
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4338, dtype: int64

# %% [markdown]
# 12) Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# 13) Import The model

# %%
from sklearn.linear_model import LinearRegression

# %%
data.head()
# Out:
#                        name  selling_price  km_driven  fuel  seller_type  \
# 0             Maruti 800 AC          60000      70000     4            0
# 1  Maruti Wagon R LXI Minor         135000      50000     4            0
# 2      Hyundai Verna 1.6 SX         600000     100000     0            0
# 3    Datsun RediGO T Option         250000      46000     4            0
# 4     Honda Amaze VX i-DTEC         450000     141000     0            0
#
#    transmission  owner  Age
# 0             0      0   17
# 1             0      0   17
# 2             0      0   12
# 3             0      0    7
# 4             0      1   10

# %%
X_train = X_train.dropna()

# %% [markdown]
# 14) Model Training

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 15) Prediction on Test Data

# %%
y_pred1 = lr.predict(X_test)

# %% [markdown]
# 16) Evaluating the Algorithm

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)

# %%
print(score1)
# Out:
# 0.39424462743829713

# %%
final_data = pd.DataFrame({'Models':['LR'],
             "R2_SCORE":[score1,]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.394245

# %%
sns.barplot(x=final_data['Models'], y=final_data['R2_SCORE'])
# Out:
# <Axes: xlabel='Models', ylabel='R2_SCORE'>

# %% [markdown]
# 17) Save The Model

# %%
lr = LinearRegression()
lr_final = lr.fit(X,y)

# %%
joblib.dump(lr_final,'car_price_prediction')
# Out:
# ['car_price_prediction']

# %%
model = joblib.load('car_price_prediction')

# %% [markdown]
# 18) Prediction on New Data

# %%
import pandas as pd
data_new = pd.DataFrame({
    'km_driven':98000,
    'fuel':4,
    'seller_type':0,
    'transmission':1,
    'owner':0,
    'Age':5
},index=[0])

# %% [markdown]
# 19) Predicated answer

# %%
result = model.predict(data_new)
rounded_result = round(result[0], 2)
print("Car Purchase amount:", rounded_result)
# Out:
# Car Purchase amount: 1274754.97

# %% [markdown]
# 20) Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
model = GaussianNB()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
accuracy = (predictions == y_test).mean()
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.06221198156682028

# %% [markdown]
# 21) KMean Clustering

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

df = pd.DataFrame(data)
label_encoder = LabelEncoder()
df['fuel'] = label_encoder.fit_transform(df['fuel'])
df['seller_type'] = label_encoder.fit_transform(df['seller_type'])
df['transmission'] = label_encoder.fit_transform(df['transmission'])
df['owner'] = label_encoder.fit_transform(df['owner'])
X = df[[ 'selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission', 'owner']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_scaled)
df['cluster'] = kmeans.labels_
print(df)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis', marker='o', edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1 (Standardized)')
plt.ylabel('Feature 2 (Standardized)')
plt.legend()
plt.show()
# Out:
#                                      name  selling_price  km_driven  fuel  \
# 0                           Maruti 800 AC          60000      70000     4
# 1                Maruti Wagon R LXI Minor         135000      50000     4
# 2                    Hyundai Verna 1.6 SX         600000     100000     0
# 3                  Datsun RediGO T Option         250000      46000     4
# 4                   Honda Amaze VX i-DTEC         450000     141000     0
# ...                                   ...            ...        ...   ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999      80000     0
# 4336           Hyundai i20 Magna 1.4 CRDi         409999      80000     0
# 4337                  Maruti 800 AC BSIII         110000      83000     4
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000      90000     0
# 4339                     Renault KWID RXT         225000      40000     4
#
#       seller_type  transmission  owner  Age  cluster
# ...

# %% [markdown]
# 22) KNN

# %%
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
X, y = make_blobs(n_samples = 500, n_features = 2, centers = 4,cluster_std = 1.5, random_state = 4)

# %%
plt.style.use('seaborn')
plt.figure(figsize = (10,10))
plt.scatter(X[:,0], X[:,1], c=y, marker= '+',s=100,edgecolors='black')
plt.show()

# %%
knn5 = KNeighborsClassifier(n_neighbors = 5)
knn1 = KNeighborsClassifier(n_neighbors=1)

# %%
knn5.fit(X_train, y_train)
knn1.fit(X_train, y_train)

y_pred_5 = knn5.predict(X_test)
y_pred_1 = knn1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy with k=5", accuracy_score(y_test, y_pred_5)*100)
print("Accuracy with k=1", accuracy_score(y_test, y_pred_1)*100)
# Out:
# Accuracy with k=5 12.442396313364055
# Accuracy with k=1 22.465437788018434

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.scatter(X_test.iloc[:,0], X_test.iloc[:,1], c=y_pred_5, marker= '+', s=100,edgecolors='black')
plt.title("Predicted values with k=5", fontsize=20)

plt.subplot(1,2,2)
plt.scatter(X_test.iloc[:,0], X_test.iloc[:,1], c=y_pred_1, marker= '+', s=100,edgecolors='black')
plt.title("Predicted values with k=1", fontsize=20)
plt.show()

# %% [markdown]
# 23) Neural Network

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train_scaled, y_train, epochs=5, batch_size=32, validation_data=(X_test_scaled, y_test))
loss = model.evaluate(X_test_scaled, y_test)
print(f'Mean Squared Error on Test Data: {loss}')

predictions = model.predict(X_test_scaled)
# Out:
# Epoch 1/5
# 109/109 [==============================] - 4s 5ms/step - loss: 567623942144.0000 - val_loss: 506821771264.0000
# Epoch 2/5
# 109/109 [==============================] - 0s 4ms/step - loss: 567351640064.0000 - val_loss: 506285162496.0000
# Epoch 3/5
# 109/109 [==============================] - 0s 4ms/step - loss: 566172516352.0000 - val_loss: 504610455552.0000
# Epoch 4/5
# 109/109 [==============================] - 0s 4ms/step - loss: 563384025088.0000 - val_loss: 501265793024.0000
# Epoch 5/5
# ...
# 28/28 [==============================] - 0s 2ms/step - loss: 495548334080.0000
# Mean Squared Error on Test Data: 495548334080.0
# 28/28 [==============================] - 0s 2ms/step

# %%
plt.scatter(y_test, predictions, alpha=0.5)
plt.title('Actual vs Predicted Ages')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.show()
